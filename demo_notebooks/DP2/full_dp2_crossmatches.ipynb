# %%
import lsdb
from upath import UPath
from dask.distributed import Client
from lsdb.streams import CatalogStream
import pandas as pd
import matplotlib.pyplot as plt

# %%
print(lsdb.__version__)
# Out:
# 0.10.1

# %% [markdown]
# # Using LSDB to Perform Large Crossmatches with Data Preview 2 (DP2)
#
# In this notebook we'll show how to:
#
# * Load the hats-formatted version of DP2 on the Rubin Science Platform (RSP)
# * Load an external hats catalogs
# * Apply column-based filtering on catalogs
# * Perform large crossmatches between DP2 and other catalogs
# * Demonstrate how to use Catalog streaming to overcome significant data volume
# * Plot some resulting lightcurves

# %% [markdown]
# ## Load Data Preview 2
#
# We begin by loading in DP2, specifying just ra and dec columns to have the lightest weight catalog possible. In practice, trimming down columns to only the subset you'll need for analysis can greatly help in avoiding memory-related issues during computation.
#
# > **Tip**: It's fine to load them all lazily at first and then trim down later once you've solidified a workflow.

# %%
dp2_path = "/sdf/data/rubin/shared/lsdb_commissioning/hats/dp2_rc/object_collection" # replace with proper DP2 path
#dp2_path = UPath("/rubin/lsdb_data/object_collection")

dp2 = lsdb.open_catalog(dp2_path, columns=["coord_ra", "coord_dec"])
dp2
# Out:
# lsdb Catalog object_lc:
#                                coord_ra        coord_dec
# npartitions=8840
# Order: 8, Pixel: 10240  double[pyarrow]  double[pyarrow]
# ...                                 ...              ...
# Order: 5, Pixel: 12283              ...              ...
# Order: 5, Pixel: 12284              ...              ...
# 2 out of 1261 available columns in the catalog have been loaded lazily, meaning no data has been read, only the catalog schema
# This catalog has an estimated size of 18.9 GB

# %% [markdown]
# ## Load another Catalog - Gaia DR3
#
# We'll now load Gaia remotely as a second catalog for future crossmatching. Again, we're limiting our column loading to only columns we'll need.

# %%
# Open from a remote s3 bucket
gaia = lsdb.open_catalog('s3://stpubdata/gaia/gaia_dr3/public/hats',
                        columns=["ra", "dec", "parallax", 'parallax_over_error', 'teff_gspphot', 'logg_gspphot', 'classprob_dsc_combmod_star'])
gaia
# Out:
# lsdb Catalog gaia:
#                                    ra              dec         parallax parallax_over_error    teff_gspphot    logg_gspphot classprob_dsc_combmod_star
# npartitions=2016
# Order: 2, Pixel: 0    double[pyarrow]  double[pyarrow]  double[pyarrow]      float[pyarrow]  float[pyarrow]  float[pyarrow]             float[pyarrow]
# ...                               ...              ...              ...                 ...             ...             ...                        ...
# Order: 3, Pixel: 766              ...              ...              ...                 ...             ...             ...                        ...
# Order: 3, Pixel: 767              ...              ...              ...                 ...             ...             ...                        ...
# 7 out of 152 available columns in the catalog have been loaded lazily, meaning no data has been read, only the catalog schema
# This catalog has an estimated size of 87.0 GB

# %% [markdown]
# ### Query Gaia: Filtering for FGK Stars
#
# `Catalog.query` allows us to apply filters based on column values, in this case we'll apply a set of cuts to select for FGK Stars.

# %%
gaia_filtered = gaia.query(
    "parallax > 0 and parallax_over_error > 5 and \
    teff_gspphot > 5380 and teff_gspphot < 7220 and logg_gspphot > 4.5 \
    and logg_gspphot < 4.72 and classprob_dsc_combmod_star > 0.5"
)

# %% [markdown]
# ### Perform a Crossmatch
#
# Now we're ready to crossmatch DP2 and our filtered Gaia DR3.

# %%
xmatch = dp2.crossmatch(gaia_filtered, suffix_method="overlapping_columns")
xmatch
# Out:
# lsdb Catalog object_lc_x_gaia:
#                                coord_ra        coord_dec               ra              dec         parallax parallax_over_error    teff_gspphot    logg_gspphot classprob_dsc_combmod_star     _dist_arcsec
# npartitions=9139
# Order: 8, Pixel: 10240  double[pyarrow]  double[pyarrow]  double[pyarrow]  double[pyarrow]  double[pyarrow]      float[pyarrow]  float[pyarrow]  float[pyarrow]             float[pyarrow]  double[pyarrow]
# ...                                 ...              ...              ...              ...              ...                 ...             ...             ...                        ...              ...
# Order: 5, Pixel: 12283              ...              ...              ...              ...              ...                 ...             ...             ...                        ...              ...
# Order: 5, Pixel: 12284              ...              ...              ...              ...              ...                 ...             ...             ...                        ...              ...
# 10 out of 10 available columns in the catalog have been loaded lazily, meaning no data has been read, only the catalog schema

# %% [markdown]
# ## Count the Resulting Matches
#
# At this point, we're just interested in the number of matches we found, so we'll construct a small function to apply through `Catalog.map_partition` which counts the number of matches in each output partition.

# %%
# Write a simple map_partitions function to count resulting matches
def count_matches(df):
    return {"n_matches": len(df)}

matches_by_partition = xmatch.map_partitions(count_matches)

# %% [markdown]
# ## Performing Computation
#
# For computation, we establish a Dask Client and dictate a number of workers and memory limit per worker. The Dask client will work within it's boundaries to perform the computation that we kick off with `Catalog.compute()` in parallel.

# %%
# Define a client, and .compute() the match result
with Client(n_workers=4, threads_per_worker=1, memory_limit="4GB") as client:
    match_df = matches_by_partition.compute()
    client.close()
# Out:
# Computing Catalog:   0%|          | 0/9139 [00:00<?, ?it/s]

# %% [markdown]
# Finally we can check the total number of Gaia-filtered FGK stars we matched in DP2:

# %%
print(f"Number of Matches: {match_df["n_matches"].sum()}")
# Out:
# Number of Matches: 548168

# %% [markdown]
# ## Including Lightcurves
# Let's start again, but this time we'll add the "ObjectForcedSource" column, which includes our lightcurves, with the goal of inspecting a few of them.

# %%
dp2_lc = lsdb.open_catalog(dp2_path, columns=["coord_ra", "coord_dec", "objectForcedSource"])
dp2_lc
# Out:
# lsdb Catalog object_lc:
#                                coord_ra        coord_dec                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                objectForcedSource
# npartitions=8840
# Order: 8, Pixel: 10240  double[pyarrow]  double[pyarrow]  nested<parentObjectId: [int64], coord_ra: [double], coord_dec: [double], visit: [int64], detector: [int16], band: [string], psfFlux: [float], psfFluxErr: [float], psfFlux_flag: [bool], psfDiffFlux: [float], psfDiffFluxErr: [float], psfDiffFlux_flag: [bool], diff_PixelFlags_nodataCenter: [bool], pixelFlags_bad: [bool], pixelFlags_cr: [bool], pixelFlags_crCenter: [bool], pixelFlags_edge: [bool], pixelFlags_interpolated: [bool], pixelFlags_interpolatedCenter: [bool], pixelFlags_nodata: [bool], pixelFlags_saturated: [bool], pixelFlags_saturatedCenter: [bool], pixelFlags_suspect: [bool], pixelFlags_suspectCenter: [bool], invalidPsfFlag: [bool], tract: [int64], patch: [int64], psfMag: [float], psfMagErr: [float], midpointMjdTai: [double], psfFluxErr_corrected: [float], psfFluxErr_corrected_flag: [bool], psfDiffFluxErr_corrected: [float], psfDiffFluxErr_corrected_flag: [bool], psfMagErr_corrected: [float]>
# ...                                 ...              ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# Order: 5, Pixel: 12283              ...              ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# Order: 5, Pixel: 12284              ...              ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 3 out of 1261 available columns in the catalog have been loaded lazily, meaning no data has been read, only the catalog schema
# This catalog has an estimated size of 1.3 TB

# %% [markdown]
# A common operation is to filter lightcurve lengths, we lack a pre-existing column to tell us the lengths, so we'll take advantage of our nested column itself to perform the filter:

# %%
#query for lightcurves with at least 50 observations
def filter_lengths(nf):
    # define a function that applies to each dataframe partition
    return nf[nf["objectForcedSource"].len() > 50] # nested columns have a direct len()

dp2_lc_filtered = dp2_lc.map_partitions(filter_lengths)

# %% [markdown]
# Now we can redo our crossmatch with Gaia:

# %%
xmatch_lc = dp2_lc_filtered.crossmatch(gaia_filtered, suffix_method="overlapping_columns")
xmatch_lc
# Out:
# lsdb Catalog object_lc_x_gaia:
#                                coord_ra        coord_dec                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                objectForcedSource               ra              dec         parallax parallax_over_error    teff_gspphot    logg_gspphot classprob_dsc_combmod_star     _dist_arcsec
# npartitions=9139
# Order: 8, Pixel: 10240  double[pyarrow]  double[pyarrow]  nested<parentObjectId: [int64], coord_ra: [double], coord_dec: [double], visit: [int64], detector: [int16], band: [string], psfFlux: [float], psfFluxErr: [float], psfFlux_flag: [bool], psfDiffFlux: [float], psfDiffFluxErr: [float], psfDiffFlux_flag: [bool], diff_PixelFlags_nodataCenter: [bool], pixelFlags_bad: [bool], pixelFlags_cr: [bool], pixelFlags_crCenter: [bool], pixelFlags_edge: [bool], pixelFlags_interpolated: [bool], pixelFlags_interpolatedCenter: [bool], pixelFlags_nodata: [bool], pixelFlags_saturated: [bool], pixelFlags_saturatedCenter: [bool], pixelFlags_suspect: [bool], pixelFlags_suspectCenter: [bool], invalidPsfFlag: [bool], tract: [int64], patch: [int64], psfMag: [float], psfMagErr: [float], midpointMjdTai: [double], psfFluxErr_corrected: [float], psfFluxErr_corrected_flag: [bool], psfDiffFluxErr_corrected: [float], psfDiffFluxErr_corrected_flag: [bool], psfMagErr_corrected: [float]>  double[pyarrow]  double[pyarrow]  double[pyarrow]      float[pyarrow]  float[pyarrow]  float[pyarrow]             float[pyarrow]  double[pyarrow]
# ...                                 ...              ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...              ...              ...              ...                 ...             ...             ...                        ...              ...
# Order: 5, Pixel: 12283              ...              ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...              ...              ...              ...                 ...             ...             ...                        ...              ...
# Order: 5, Pixel: 12284              ...              ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...              ...              ...              ...                 ...             ...             ...                        ...              ...
# 11 out of 11 available columns in the catalog have been loaded lazily, meaning no data has been read, only the catalog schema

# %%
# And re-initialize our counting result
def count_matches(df):
    return {"n_matches": len(df)}

matches_by_partition_lc = xmatch_lc.map_partitions(count_matches)

# %% [markdown]
# ## Dealing with Heavy Workloads - Catalog Streaming

# %% [markdown]
# However, our added lightcurves add a ton of weight to the DP2 catalog. If you check the estimated catalog size when we first loaded the catalogs, you can see that DP2 was ~20GB total when loading just the "coord_ra" and "coord_dec" columns, but with "objectForcedSource" this balloons to ~1.3TB. Due to this, it's likely that direct computation on a RSP environment (4 cores, 32GB total) will fail. We can take advantage of an alternative computation method, Catalog Streaming, in cases like this:

# %%
# %%time
match_stream = CatalogStream(xmatch_lc, partitions_per_chunk=4, shuffle=False)

chunks = []
# 16 GB workers end up being needed to perform this workflow
with Client(n_workers=1, memory_limit="16GB") as client:
    match_iter = iter(match_stream)
    for i in range(20):
        chunks.append(next(match_iter))        
    client.close()
match_df = pd.concat(chunks)
match_df
# Out:
# CPU times: user 4.49 s, sys: 869 ms, total: 5.36 s
# Wall time: 1min 41s
#                        coord_ra  coord_dec  \
# _healpix_29
# 3452204825677797065  305.946264 -10.583908
# 3452205377521584693   305.72863 -10.691067
# 3452216821237142673  305.824922 -10.395305
# 3452218383995908147  305.850041 -10.357047
# 3452187698109812560  305.430909 -10.953104
# 3452187848933175089  305.369405 -10.966587
# 3452187871334038380  305.409641 -10.966195
# 3452187880769951138    305.4055 -10.959847
# 3452188014153292605   305.39645 -10.939763
# 3452188204713095938  305.401243 -10.928789
# 3452195368198065825  305.456162 -10.807176
#
#                                                     objectForcedSource  \
# _healpix_29
# 3452204825677797065  [{parentObjectId: 0, coord_ra: 305.946264, coo...
# 3452205377521584693  [{parentObjectId: 0, coord_ra: 305.72863, coor...
# 3452216821237142673  [{parentObjectId: 0, coord_ra: 305.824922, coo...
# 3452218383995908147  [{parentObjectId: 0, coord_ra: 305.850041, coo...
# 3452187698109812560  [{parentObjectId: 0, coord_ra: 305.430909, coo...
# 3452187848933175089  [{parentObjectId: 0, coord_ra: 305.369405, coo...
# 3452187871334038380  [{parentObjectId: 0, coord_ra: 305.409641, coo...
# 3452187880769951138  [{parentObjectId: 0, coord_ra: 305.4055, coord...
# 3452188014153292605  [{parentObjectId: 0, coord_ra: 305.39645, coor...
# 3452188204713095938  [{parentObjectId: 0, coord_ra: 305.401243, coo...
# 3452195368198065825  [{parentObjectId: 0, coord_ra: 305.456162, coo...
#
#                              ra        dec  parallax  parallax_over_error  \
# _healpix_29
# 3452204825677797065  305.946255 -10.583901  0.710761            20.467844
# 3452205377521584693  305.728641 -10.691061  0.460955            10.544349
# 3452216821237142673   305.82493 -10.395294  0.469625             6.168673
# 3452218383995908147  305.850029 -10.357021  1.189362            34.080879
# 3452187698109812560  305.430911 -10.953095  0.358552             5.336546
# 3452187848933175089  305.369415 -10.966587  0.358569             6.519283
# 3452187871334038380  305.409625 -10.966191   0.57091            10.966236
# 3452187880769951138  305.405491 -10.959815  0.397594             7.861736
# 3452188014153292605  305.396443 -10.939731  0.465404             8.661577
# 3452188204713095938  305.401246 -10.928773  0.614874             11.13603
# 3452195368198065825  305.456153 -10.807178  0.334579             5.229875
#
#                      teff_gspphot  logg_gspphot  classprob_dsc_combmod_star  \
# _healpix_29
# 3452204825677797065    5504.50293        4.5516                    0.999955
# 3452205377521584693   5609.919922        4.5009                    0.999961
# 3452216821237142673    5459.34668        4.6765                    0.999966
# 3452218383995908147   5504.515137        4.5091                    0.999954
# 3452187698109812560   5449.150879        4.6361                    0.999985
# 3452187848933175089   5524.895996        4.5901                    0.999978
# 3452187871334038380   5419.901367        4.5864                    0.999981
# 3452187880769951138   5597.873047         4.531                    0.999986
# 3452188014153292605   5557.198242         4.561                     0.99997
# 3452188204713095938   5380.835938        4.6351                    0.999987
# 3452195368198065825   5391.723145         4.556                     0.99998
#
#                      _dist_arcsec
# _healpix_29
# 3452204825677797065      0.039326
# 3452205377521584693      0.046429
# 3452216821237142673      0.047867
# 3452218383995908147      0.102755
# 3452187698109812560      0.033853
# 3452187848933175089      0.034122
# 3452187871334038380      0.060626
# 3452187880769951138      0.117208
# 3452188014153292605      0.120047
# 3452188204713095938      0.060026
# 3452195368198065825      0.030314

# %% [markdown]
# Above, we've streamed the result for the first 80 partitions (4 partitions per chunk, 20 chunks grabbed). We ultimately found 11 lightcurves that matched our criteria. Let's end by plotting one of them:

# %%
lc = match_df.iloc[0]["objectForcedSource"]
lc
# Out:
#     parentObjectId    coord_ra  coord_dec          visit  detector band  \
# 0                0  305.946264 -10.583908  2025062000415        11    i
# 1                0  305.946264 -10.583908  2025062000458       181    i
# ..             ...         ...        ...            ...       ...  ...
# 51               0  305.946264 -10.583908  2025072800441        14    i
# 52               0  305.946264 -10.583908  2025072800489        14    z
#
#          psfFlux   psfFluxErr  psfFlux_flag   psfDiffFlux  ...  tract  patch  \
# 0   4.204871e+05   551.586121         False -2.398203e+06  ...   7743     83
# 1   3.382192e+06  1910.429321         False  4.734175e+05  ...   7743     83
# ..           ...          ...           ...           ...  ...    ...    ...
# 51  3.349842e+06  1852.315796         False  3.979522e+05  ...   7743     83
# 52  3.589231e+06  2230.597900         False  7.802666e+05  ...   7743     83
#
#        psfMag  psfMagErr  midpointMjdTai  psfFluxErr_corrected  \
# 0   17.340618   0.001424    60847.236666           4696.559570
# 1   15.077004   0.000613    60847.256542          30366.257812
# ..        ...        ...             ...                   ...
# 51  15.087439   0.000600    60885.357343          30350.798828
# 52  15.012497   0.000675    60885.380867          32634.371094
#
#     psfFluxErr_corrected_flag  psfDiffFluxErr_corrected  \
# 0                       False               2157.076660
# 1                       False               4757.828613
# ..                        ...                       ...
# 51                      False               4599.051758
# 52                      False               6119.346680
#
#     psfDiffFluxErr_corrected_flag  psfMagErr_corrected
# 0                           False             0.012127
# 1                           False             0.009748
# ..                            ...                  ...
# 51                          False             0.009837
# 52                          False             0.009872
#
# [53 rows x 35 columns]

# %%
plt.plot(lc["midpointMjdTai"],lc["psfMag"],'.')

# %% [markdown]
# ## Summary
#
# With an RSP-sized environment, it's possible to do large crossmatches between DP2 and other large hats catalogs, as long as you are mindful of the columns being loaded and the Dask Client setup you are specifying for computation. Note how much the computational approach needed to change just by including lightcurves from "objectForcedSource". Being aware of the computational weight of your workflows is it's own learning curve, even as LSDB tries to assist as much as it can with this.
#
# If you're looking for more tips on doing large scale workflows, consult the [LSDB documentation](https://docs.lsdb.io/en/stable/tutorials/dask-cluster-tips.html).
